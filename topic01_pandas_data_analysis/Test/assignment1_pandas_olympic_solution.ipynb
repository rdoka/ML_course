# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko) and Vadim Shestopalov (@vchulski). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center>Assignment #1. Fall 2019
# ## <center>Exploratory data analysis of Olympic games with Pandas
#
# <img src='../../img/olympic_logo.png' width=50%>

# %% [markdown]
# Prior to working on the assignment, you'd better check out the corresponding course material:
#  - [Exploratory data analysis with Pandas](https://nbviewer.jupyter.org/github/Yorko/mlcourse_open/blob/master/jupyter_english/topic01_pandas_data_analysis/topic1_pandas_data_analysis.ipynb?flush_cache=true), the same as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas)
#  - first lectures in mlcourse.ai [YouTube playlist ](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
#  - you can also practice with demo assignments, which are simpler and already shared with solutions: [A1 demo](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset), [solution](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset-solution)
#
# ### Your task is to:
#  1. write code and perform computations in the cells below
#  2. choose answers in the [webform](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU). Solutions will be shared only with those who've filled in this form
#  3. submit answers with some email and **remember it**! This will be your ID during the course. Specify your real full name in the form as well (no nicks allowed in the final top-100 [rating](https://mlcourse.ai/rating)). If in doubt, you can re-submit the form till the deadline for A1, no problem, but stick to only one email.
#
# ### <center> Deadline for A1: 2019 September 15, 20:59 GMT (London time)
#
# You'll get up to 10 credits for this assignment.
#
# ### How to get help
# In [ODS Slack](https://opendatascience.slack.com) (if you still don't have access, fill in the [form](https://docs.google.com/forms/d/10HAN5huM996snUKjsNYyT_oOlm2uOsTKulKurb3oiNM/) mentioned on the mlcourse.ai main page), we have a channel **#mlcourse_ai_news** with announcements from the course team.
# You can discuss the course content freely in the **#mlcourse_ai** channel (we still have a huge Russian-speaking group, they have a separate channel **#mlcourse_ai_rus**).
#
# Here's how you reply in a thread (press this dialog icon to drill down into a thread):
#
# <img src="../../img/start_a_thread.png" />
#
# Please stick to special threads *a1_q1-5_fall2019* and *a1_q6-10_fall2019* in **#mlcourse_ai_news** for your questions on A1. Help each other without sharing correct code and answers. Our TA **Vadim @vchulski** is there to help (only in the mentioned thread, do not write to him directly).
#
# Lastly, you can save useful messages by pinning them, further you can find pinned items on the top, just below the channel name:
#
# <img src="../../img/pinned_item.png" />
#
# ### Assignment
# __There are ten questions about 120 years of Olympic history in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU).__

# %% [markdown]
# Download the file `athlete_events.csv` from [here](https://drive.google.com/file/d/1f5v6Z2ayc7h698FG_98wP5x1Y2zZQeox/view?usp=sharing) (scraped by [rgriffin](https://www.randigriffin.com/) from www.sports-reference.com). The dataset has the following features:
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd

# %%
# Change the path to the dataset file if needed. 
PATH = 'datasets/athlete_events.csv'

# %%
data = pd.read_csv(PATH)
data.sample(10)
# Out:
#             ID                                      Name Sex   Age  Height  \
# 180147   90532               Giovanni Battista Paganelli   M  23.0   186.0
# 24361    12766               Wendy Lou Lansbach Boglioli   F  21.0   180.0
# 116552   58976                            Lauri Kettunen   M  23.0     NaN
# 51075    26246  Luc Henri Herv Guy Gardye de la Chapelle   M  31.0     NaN
# 202987  101942              Annette Joan Rogers (-Kelly)   F  22.0   162.0
# 140961   70760                     Diego Lizardi Marcial   M  24.0   165.0
# 27075    14083                           Marcel Bouraine   M   NaN     NaN
# 197493   99155                          Hubert Raudaschl   M  22.0   187.0
# 58126    29751                      Robert Jeffrey Dover   M  36.0   178.0
# 103590   52411           Vladimir Nikolayevich Isachenko   M  33.0   194.0
#
#         Weight           Team  NOC        Games  Year  Season            City  \
# 180147    90.0          Italy  ITA  1976 Summer  1976  Summer        Montreal
# 24361     64.0  United States  USA  1976 Summer  1976  Summer        Montreal
# 116552     NaN        Finland  FIN  1928 Summer  1928  Summer       Amsterdam
# 51075      NaN       France-1  FRA  1900 Summer  1900  Summer           Paris
# 202987    50.0  United States  USA  1936 Summer  1936  Summer          Berlin
# 140961    65.0    Puerto Rico  PUR  2000 Summer  2000  Summer          Sydney
# 27075      NaN         France  FRA  1924 Summer  1924  Summer           Paris
# 197493    82.0        Austria  AUT  1964 Summer  1964  Summer           Tokyo
# 58126     68.0  United States  USA  1992 Summer  1992  Summer       Barcelona
# 103590    90.0     Kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
#
#                    Sport                                         Event   Medal
# 180147            Rowing                      Rowing Men's Coxed Fours     NaN
# 24361           Swimming  Swimming Women's 4 x 100 metres Medley Relay  Silver
# 116552           Fencing                Fencing Men's epee, Individual     NaN
# 51075             Tennis                          Tennis Men's Doubles  Bronze
# 202987         Athletics                   Athletics Women's High Jump     NaN
# 140961        Gymnastics               Gymnastics Men's Horizontal Bar     NaN
# 27075   Art Competitions            Art Competitions Mixed Sculpturing     NaN
# 197493           Sailing               Sailing Mixed One Person Dinghy     NaN
# 58126      Equestrianism            Equestrianism Mixed Dressage, Team  Bronze
# 103590          Shooting          Shooting Men's Air Pistol, 10 metres     NaN

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1992 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 16 and 15
# - 14 and 13
# - 13 and 11
# - 11 and 12

# %%
# You code1 here
(data[(data['Year']==1992) & (data['Sex']=='M')].Age.min(),data[(data['Year']==1992) & (data['Sex']=='F')].Age.min())
# Out:
# (11.0, 12.0)

# %%
# You code2 here
data[data['Year']==1992].sort_values(by='Age').head()
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 73461    37333  Carlos Bienvenido Front Barrera   M  11.0     NaN     NaN
# 120234   60854                       Judit Kiss   F  12.0   171.0    57.0
# 120233   60854                       Judit Kiss   F  12.0   171.0    57.0
# 80831    41040       Gina Elena Gogean (-Groza)   F  13.0   150.0    40.0
# 265499  132855          Wei Ling "Joscelin" Yeo   F  13.0   165.0    56.0
#
#              Team  NOC        Games  Year  Season       City       Sport  \
# 73461       Spain  ESP  1992 Summer  1992  Summer  Barcelona      Rowing
# 120234    Hungary  HUN  1992 Summer  1992  Summer  Barcelona    Swimming
# 120233    Hungary  HUN  1992 Summer  1992  Summer  Barcelona    Swimming
# 80831     Romania  ROU  1992 Summer  1992  Summer  Barcelona  Gymnastics
# 265499  Singapore  SGP  1992 Summer  1992  Summer  Barcelona    Swimming
#
#                                                 Event Medal
# 73461                       Rowing Men's Coxed Eights   NaN
# 120234          Swimming Women's 800 metres Freestyle   NaN
# 120233          Swimming Women's 400 metres Freestyle   NaN
# 80831                 Gymnastics Women's Balance Beam   NaN
# 265499  Swimming Women's 200 metres Individual Medley   NaN

# %% [markdown]
# __2. What was the percentage of male basketball players among all the male participants of the 2012 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0.2
# - 1.5
# - 2.5
# - 7.7

# %%
# You code here
data1=data[(data['Year']==2012)&(data['Sex']=='M')]
data2=data1.drop_duplicates('ID')

n_men=data2.Sex.count()
n_men_basket=data2[data2['Sport']=='Basketball'].Sport.count()

print(n_men_basket)
print(n_men)
#print(n_men_basket[0]/n_men[0])
print(round(n_men_basket/n_men,3)*100)
# Out:
# 144
# 5863
# 2.5

# %% [markdown]
# __3. What are the mean and standard deviation of height for female tennis players who participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 171.8 and 6.5
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %%
# You code here
data3=data[(data.Year==2000)&(data.Sport=='Tennis')&(data.Sex=='F')]
data3.describe()
# Out:
#                   ID         Age      Height      Weight    Year
# count     126.000000  126.000000  125.000000  125.000000   126.0
# mean    76328.388889   23.396825  171.792000   61.536000  2000.0
# std     39698.652992    3.516997    6.458673    5.908638     0.0
# min      4723.000000   17.000000  150.000000   52.000000  2000.0
# 25%     42905.750000   21.000000  168.000000   57.000000  2000.0
# 50%     75706.000000   24.000000  172.000000   60.000000  2000.0
# 75%    115461.500000   26.000000  176.000000   65.000000  2000.0
# max    135502.000000   30.000000  191.000000   79.000000  2000.0

# %% [markdown]
# __4. Find a sportsman who participated in the 2006 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - Judo
# - Bobsleigh
# - Skeleton
# - Boxing

# %%
# You code here
data[(data.Year==2006)].sort_values('Weight',ascending=False)
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 8102      4476                   Patrick R. Antaki   M  41.0   185.0   127.0
# 38615    19867                          Zdeno Chra   M  28.0   206.0   116.0
# 129597   65246                         Kevin Kuske   M  27.0   196.0   116.0
# 129596   65246                         Kevin Kuske   M  27.0   196.0   116.0
# 48536    25017          Matthew John "Matt" Dallow   M  34.0   190.0   114.0
# 128126   64528                        Pavel Kubina   M  28.0   196.0   113.0
# 20721    10933                       Todd Bertuzzi   M  31.0   191.0   111.0
# 111387   56361                        Milan Jurina   M  22.0   195.0   110.0
# 93071    47140                          Beat Hefti   M  28.0   183.0   110.0
# 93070    47140                          Beat Hefti   M  28.0   183.0   110.0
# 100887   51009              Daniel "Dan" Humphries   M  26.0   193.0   108.0
# 100886   51009              Daniel "Dan" Humphries   M  26.0   193.0   108.0
# 58578    29972                   Daumants Dreikens   M  21.0   193.0   108.0
# 58577    29972                   Daumants Dreikens   M  21.0   193.0   108.0
# 91881    46566                 Derian John Hatcher   M  33.0   195.0   107.0
# 92541    46875                    Todd Dennys Hays   M  36.0   190.0   107.0
# 92542    46875                    Todd Dennys Hays   M  36.0   190.0   107.0
# 48998    25251                        Ivo Danilevi   M  35.0   188.0   107.0
# 95518    48361                    Christoph Heyder   M  31.0   194.0   107.0
# 48997    25251                        Ivo Danilevi   M  35.0   188.0   107.0
# 77507    39330                 Andreas "Andi" Gees   M  30.0   183.0   106.0
# 72546    36895             Johann "Hans" Frauenlob   M  45.0   187.0   105.0
# 254849  127579          Aleksey Ivanovich Voyevoda   M  25.0   195.0   105.0
# 254850  127579          Aleksey Ivanovich Voyevoda   M  25.0   195.0   105.0
# 128539   64720                           Marc Khne   M  29.0   197.0   105.0
# 125792   63458    Aleksey Vyacheslavovich Kovalyov   M  32.0   177.0   105.0
# 194142   97456                     Georgijs Pujacs   M  24.0   184.0   105.0
# 203631  102234                    Samuele Romanini   M  29.0   187.0   105.0
# 203630  102234                    Samuele Romanini   M  29.0   187.0   105.0
# 125741   63436          Ilya Valeryevich Kovalchuk   M  22.0   188.0   104.0
# ...        ...                                 ...  ..   ...     ...     ...
# 38092    19573                         Galit Chait   F  31.0   153.0    45.0
ice Hockey               Ice Hockey Men's Ice Hockey     NaN
# 111387            Ice Hockey               Ice Hockey Men's Ice Hockey     NaN
# 93071              Bobsleigh                      Bobsleigh Men's Four  Bronze
# 93070              Bobsleigh                       Bobsleigh Men's Two  Bronze
# 100887             Bobsleigh                      Bobsleigh Men's Four     NaN
# 100886             Bobsleigh                       Bobsleigh Men's Two     NaN
# 58578              Bobsleigh                      Bobsleigh Men's Four     NaN
# 58577              Bobsleigh                       Bobsleigh Men's Two     NaN
# 91881             Ice Hockey               Ice Hockey Men's Ice Hockey     NaN
# 92541              Bobsleigh                       Bobsleigh Men's Two     NaN
# 92542              Bobsleigh                      Bobsleigh Men's Four     NaN
# 48998              Bobsleigh                      Bobsleigh Men's Four     NaN
# 95518              Bobsleigh                      Bobsleigh Men's Four     NaN
# 48997              Bobsleigh                       Bobsleigh Men's Two     NaN
# 77507              Bobsleigh                      Bobsleigh Men's Four     NaN
# 72546                Curling                     Curling Men's Curling     NaN
# 254849             Bobsleigh                       Bobsleigh Men's Two     NaN
# 254850             Bobsleigh                      Bobsleigh Men's Four  Silver
# 128539             Bobsleigh                       Bobsleigh Men's Two     NaN
# 125792            Ice Hockey               Ice Hockey Men's Ice Hockey     NaN
# 194142            Ice Hockey               Ice Hockey Men's Ice Hockey     NaN
# 203631             Bobsleigh                      Bobsleigh Men's Four     NaN
# 203630             Bobsleigh                       Bobsleigh Men's Two     NaN
# 125741            Ice Hockey               Ice Hockey Men's Ice Hockey     NaN
# ...                      ...                                       ...     ...
# 38092         Figure Skating          Figure Skating Mixed Ice Dancing     NaN
# 218110        Figure Skating                Figure Skating Mixed Pairs  Bronze
# 267192        Figure Skating                Figure Skating Mixed Pairs     NaN
# 242442        Figure Skating                Figure Skating Mixed Pairs    Gold
# 167920          Snowboarding             Snowboarding Women's Halfpipe     NaN
# 254115        Figure Skating                Figure Skating Mixed Pairs     NaN
# 30125           Snowboarding             Snowboarding Women's Halfpipe     NaN
# 43199         Figure Skating            Figure Skating Women's Singles  Silver
# 60666       Freestyle Skiing           Freestyle Skiing Women's Moguls     NaN
# 103190        Figure Skating                Figure Skating Mixed Pairs     NaN
# 174721        Figure Skating                Figure Skating Mixed Pairs     NaN
# 117208        Figure Skating          Figure Skating Mixed Ice Dancing     NaN
# 77462         Figure Skating            Figure Skating Women's Singles     NaN
# 188177        Figure Skating                Figure Skating Mixed Pairs     NaN
# 32001         Figure Skating                Figure Skating Mixed Pairs     NaN
# 70864          Alpine Skiing          Alpine Skiing Men's Giant Slalom     NaN
# 100598        Figure Skating            Figure Skating Women's Singles     NaN
# 109183          Snowboarding           Snowboarding Men's Boardercross     NaN
# 119378  Cross Country Skiing  Cross Country Skiing Men's 15 kilometres     NaN
# 137410        Figure Skating            Figure Skating Women's Singles     NaN
# 143044        Figure Skating          Figure Skating Mixed Ice Dancing     NaN
# 149265        Figure Skating                Figure Skating Mixed Pairs     NaN
# 209800        Figure Skating              Figure Skating Men's Singles     NaN
# 211494         Alpine Skiing          Alpine Skiing Men's Giant Slalom     NaN
# 211495         Alpine Skiing                Alpine Skiing Men's Slalom     NaN
# 211812        Figure Skating              Figure Skating Men's Singles     NaN
# 215400         Alpine Skiing               Alpine Skiing Men's Super G     NaN
# 215401         Alpine Skiing          Alpine Skiing Men's Giant Slalom     NaN
# 215402         Alpine Skiing                Alpine Skiing Men's Slalom     NaN
# 261779        Figure Skating          Figure Skating Mixed Ice Dancing     NaN
#
# [4382 rows x 15 columns]

# %% [markdown]
# __5. How many times did John Aalberg participate in the Olympics held in different years?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
# You code here
data[data['Name']=='John Aalberg']
# Out:
#     ID          Name Sex   Age  Height  Weight           Team  NOC  \
# 18   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 19   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 20   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 21   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 22   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 23   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 24   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 25   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 18  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 19  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 20  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 21  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 22  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 23  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 24  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 25  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
#                                                 Event Medal
# 18           Cross Country Skiing Men's 10 kilometres   NaN
# 19           Cross Country Skiing Men's 50 kilometres   NaN
# 20  Cross Country Skiing Men's 10/15 kilometres Pu...   NaN
# 21  Cross Country Skiing Men's 4 x 10 kilometres R...   NaN
# 22           Cross Country Skiing Men's 10 kilometres   NaN
# 23           Cross Country Skiing Men's 30 kilometres   NaN
# 24  Cross Country Skiing Men's 10/15 kilometres Pu...   NaN
# 25  Cross Country Skiing Men's 4 x 10 kilometres R...   NaN

# %% [markdown]
# __6. How many gold medals in tennis did sportspeople from the Switzerland team win at the 2008 Olympics? Count every medal from every sportsperson.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
# You code here
data[(data['Year']==2008)&(data.Sport=='Tennis')&(data.Team=='Switzerland')&(data.Medal=='Gold')]
# Out:
#             ID                Name Sex   Age  Height  Weight         Team  \
# 67290    34396       Roger Federer   M  26.0   185.0    80.0  Switzerland
# 257672  129042  Stanislas Wawrinka   M  23.0   183.0    79.0  Switzerland
#
#         NOC        Games  Year  Season     City   Sport                 Event  \
# 67290   SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
# 257672  SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
#
#        Medal
# 67290   Gold
# 257672  Gold

# %% [markdown]
# __7. Is it true that Spain won fewer medals than Italy at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes
# - No

# %%
# You code here

print("Medallas de España:")
print(data[(data['Year']==2016)&(data.Team=='Spain')&(data.Medal.notnull())].Medal.count())

print("Medallas de Italia:")
print(data[(data['Year']==2016)&(data.Team=='Italy')&(data.Medal.notnull())].Medal.count())
# Out:
# Medallas de España:
# 43
# Medallas de Italia:
# 70

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2008 Olympics belong to?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - [45-55] and [25-35) correspondingly
# - [45-55] and [15-25) correspondingly
# - [35-45) and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
# You code here

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Atlanta? Is it true that there were Winter Olympics held in Squaw Valley?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes, Yes
# - Yes, No
# - No, Yes
# - No, No

# %%
# You code here

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1986 Olympics and 2002 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 3
# - 10
# - 15
# - 27

# %%
# You code here

# %% [markdown]
# That's it! Now go and do 30 push-ups! :)
